# %%
import pandas as pd

# %%
smartdf = pd.read_csv("smartphones_cleaned_v6.csv")

# %%
smartdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(smartdf['model'], smartdf['price'])
# Out:
# <BarContainer object of 980 artists>

# %%
samsung_smart_df = smartdf[smartdf['brand_name'] == 'samsung']

# %%
plt.figure(figsize=(5, 40))
plt.barh(samsung_smart_df['model'], samsung_smart_df['price'])
# Out:
# <BarContainer object of 132 artists>

# %%
apple_smart_df = smartdf[smartdf['brand_name'] == 'apple']
plt.figure(figsize=(10, 10))
plt.barh(apple_smart_df['model'], apple_smart_df['price'])
# Out:
# <BarContainer object of 46 artists>

# %%
apple_smart_df['price'].mean()
# Out:
# 95966.52173913043

# %%
samsung_smart_df['price'].mean()
# Out:
# 36843.030303030304

# %%
plt.scatter(samsung_smart_df['model'], samsung_smart_df['price'])

# %%
smartdf.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
smartdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
sorted_smart_df = smartdf.sort_values(by='rating', ascending=False)

# %%
sorted_smart_df.head()
# Out:
#     brand_name                        model  price  rating  has_5g  has_nfc  \
# 0      oneplus                OnePlus 11 5G  54999    89.0    True     True
# 359     xiaomi            Xiaomi 12T Pro 5G  59990    89.0    True     True
# 180    infinix           Infinix Zero Ultra  36999    89.0    True    False
# 694    samsung  Samsung Galaxy Note 10 Plus  58999    89.0   False     True
# 520     realme           Realme GT 2 Pro 5G  49959    89.0    True     True
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0             False      snapdragon        8.0             3.20  ...
# 359            True      snapdragon        8.0             3.20  ...
# 180           False       dimensity        8.0             2.50  ...
# 694           False          exynos        8.0             2.73  ...
# 520           False      snapdragon        8.0             3.00  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# ...

# %%
sorted_smartdf_rating_top10 = smartdf.sort_values(by='rating', ascending=False).head(10)

# %%
sorted_smartdf_rating_top10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 561
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 10 non-null     object
#  1   model                      10 non-null     object
#  2   price                      10 non-null     int64
#  3   rating                     10 non-null     float64
#  4   has_5g                     10 non-null     bool
#  5   has_nfc                    10 non-null     bool
#  6   has_ir_blaster             10 non-null     bool
#  7   processor_brand            10 non-null     object
#  8   num_cores                  10 non-null     float64
#  9   processor_speed            10 non-null     float64
#  10  battery_capacity           10 non-null     float64
#  11  fast_charging_available    10 non-null     int64
#  12  fast_charging              9 non-null      float64
# ...

# %%
plt.barh(sorted_smartdf_rating_top10['model'], sorted_smartdf_rating_top10['price'])
# Out:
# <BarContainer object of 10 artists>

# %%
sorted_smartdf_rating_top10
# Out:
#     brand_name                        model   price  rating  has_5g  has_nfc  \
# 0      oneplus                OnePlus 11 5G   54999    89.0    True     True
# 359     xiaomi            Xiaomi 12T Pro 5G   59990    89.0    True     True
# 180    infinix           Infinix Zero Ultra   36999    89.0    True    False
# 694    samsung  Samsung Galaxy Note 10 Plus   58999    89.0   False     True
# 520     realme           Realme GT 2 Pro 5G   49959    89.0    True     True
# 532        zte         ZTE Axon 40 Ultra 5G   61990    89.0    True     True
# 821     lenovo          Lenovo Legion Pro 2   59999    89.0    True     True
# 560    samsung      Samsung Galaxy Z Fold 3  110999    89.0    True     True
# 58     samsung      Samsung Galaxy S23 Plus   84990    89.0    True     True
# 561         lg                   LG Wing 5G   54999    89.0    True     True
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
sorted_smartdf_rating_top10['model']
# Out:
# 0                    OnePlus 11 5G
# 359              Xiaomi 12T Pro 5G
# 180             Infinix Zero Ultra
# 694    Samsung Galaxy Note 10 Plus
# 520             Realme GT 2 Pro 5G
# 532           ZTE Axon 40 Ultra 5G
# 821            Lenovo Legion Pro 2
# 560        Samsung Galaxy Z Fold 3
# 58         Samsung Galaxy S23 Plus
# 561                     LG Wing 5G
# Name: model, dtype: object

# %%
top50df = sorted_smart_df.head(50)

# %%
sorted_smart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 974
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 10))
plt.barh(top50df['model'], top50df['price'])
# Out:
# <BarContainer object of 50 artists>

# %%
smartdf['processor_brand'] = smartdf['processor_brand'].astype(str)
plt.figure(figsize=(10, 10))
plt.scatter(smartdf['processor_brand'], smartdf['price'])
