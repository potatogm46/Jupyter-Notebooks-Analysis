# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('fastfood.csv')

# %%
df
# Out:
#     restaurant                                       item  calories  cal_fat  \
# 0    Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1    Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2    Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3    Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4    Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
# ..         ...                                        ...       ...      ...
# 510  Taco Bell             Spicy Triple Double Crunchwrap       780      340
# 511  Taco Bell                Express Taco Salad w/ Chips       580      260
# 512  Taco Bell                     Fiesta Taco Salad-Beef       780      380
# 513  Taco Bell                  Fiesta Taco Salad-Chicken       720      320
# 514  Taco Bell                    Fiesta Taco Salad-Steak       720      320
#
# ...

# %%
df.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
df.iloc[514]
# Out:
# restaurant                   Taco Bell
# item           Fiesta Taco Salad-Steak
# calories                           720
# cal_fat                            320
# total_fat                           36
# sat_fat                            8.0
# trans_fat                          1.0
# cholesterol                         55
# sodium                            1340
# total_carb                          70
# fiber                              8.0
# sugar                                8
# protein                           28.0
# vit_a                              NaN
# vit_c                              NaN
# calcium                            NaN
# salad                            Other
# Name: 514, dtype: object

# %%
df[df['item'] == 'Fiesta Taco Salad-Steak']
# Out:
#     restaurant                     item  calories  cal_fat  total_fat  \
# 514  Taco Bell  Fiesta Taco Salad-Steak       720      320         36
#
#      sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 514      8.0        1.0           55    1340          70    8.0      8
#
#      protein  vit_a  vit_c  calcium  salad
# 514     28.0    NaN    NaN      NaN  Other

# %%
df['restaurant']
# Out:
# 0      Mcdonalds
# 1      Mcdonalds
# 2      Mcdonalds
# 3      Mcdonalds
# 4      Mcdonalds
#          ...
# 510    Taco Bell
# 511    Taco Bell
# 512    Taco Bell
# 513    Taco Bell
# 514    Taco Bell
# Name: restaurant, Length: 515, dtype: object

# %%
df['restaurant'].unique()
# Out:
# array(['Mcdonalds', 'Chick Fil-A', 'Sonic', 'Arbys', 'Burger King',
#        'Dairy Queen', 'Subway', 'Taco Bell'], dtype=object)

# %%
Chickdf = df[df['restaurant'] == 'Chick Fil-A']

# %%
Chickdf.head()
# Out:
#      restaurant                               item  calories  cal_fat  \
# 57  Chick Fil-A  Chargrilled Chicken Club Sandwich       430      144
# 58  Chick Fil-A       Chargrilled Chicken Sandwich       310       54
# 59  Chick Fil-A                     Chick-n-Slider       270       99
# 60  Chick Fil-A             1 Piece Chick-n-Strips       120       54
# 61  Chick Fil-A             2 Piece Chick-n-Strips       230      108
#
#     total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 57         16      8.0        0.0           85    1120          37    3.0
# 58          6      2.0        0.0           55     820          36    3.0
# 59         11      2.5        0.0           45     800          26    1.0
# 60          6      3.0        0.0           25     320           6    0.0
# 61         12      3.0        0.0           55     630          13    1.0
#
#     sugar  protein  vit_a  vit_c  calcium  salad
# 57      7     37.0   30.0   40.0     25.0  Other
# ...

# %%
plt.hist(Chickdf['calories'])
plt.xlabel('Calories')
plt.ylabel('Items')
# Out:
# Text(0, 0.5, 'Items')

# %%
Chickdf[Chickdf['calories'] > 600]
# Out:
#      restaurant                         item  calories  cal_fat  total_fat  \
# 69  Chick Fil-A     30 piece Chicken Nuggets       970      414         46
# 82  Chick Fil-A  Chicken Enchiladas Meal Kit       860      423         47
# 83  Chick Fil-A    Chicken Parmesan Meal Kit       720      279         31
#
#     sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 69      2.5        0.0          285    3660          35    4.0      1
# 82     16.0        1.0          100    2520          70    NaN      8
# 83     15.0        0.0          120    1780          65    NaN      7
#
#     protein  vit_a  vit_c  calcium  salad
# 69    103.0    NaN   20.0     10.0  Other
# 82     39.0    NaN    NaN      NaN  Other
# 83     48.0    NaN    NaN      NaN  Other

# %%
Chickdf[Chickdf['calories'] < 600]
# Out:
#      restaurant                                  item  calories  cal_fat  \
# 57  Chick Fil-A     Chargrilled Chicken Club Sandwich       430      144
# 58  Chick Fil-A          Chargrilled Chicken Sandwich       310       54
# 59  Chick Fil-A                        Chick-n-Slider       270       99
# 60  Chick Fil-A                1 Piece Chick-n-Strips       120       54
# 61  Chick Fil-A                2 Piece Chick-n-Strips       230      108
# 62  Chick Fil-A                3 Piece Chick-n-Strips       350      153
# 63  Chick Fil-A                4 piece Chick-n-Strips       470      207
# 64  Chick Fil-A                        Chicken Deluxe       500      207
# 65  Chick Fil-A               4 piece Chicken Nuggets       130       54
# 66  Chick Fil-A               6 piece Chicken Nuggets       190       81
# 67  Chick Fil-A               8 piece Chicken Nuggets       260      110
# 68  Chick Fil-A              12 piece Chicken Nuggets       390      162
# ...

# %%
Chickdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 57 to 83
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   27 non-null     object
#  1   item         27 non-null     object
#  2   calories     27 non-null     int64
#  3   cal_fat      27 non-null     int64
#  4   total_fat    27 non-null     int64
#  5   sat_fat      27 non-null     float64
#  6   trans_fat    27 non-null     float64
#  7   cholesterol  27 non-null     int64
#  8   sodium       27 non-null     int64
#  9   total_carb   27 non-null     int64
#  10  fiber        25 non-null     float64
#  11  sugar        27 non-null     int64
#  12  protein      27 non-null     float64
#  13  vit_a        21 non-null     float64
#  14  vit_c        25 non-null     float64
#  15  calcium      25 non-null     float64
#  16  salad        27 non-null     object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 3.8+ KB

# %%
Chickdf['calories'].mean()
# Out:
# np.float64(384.44444444444446)

# %%
simpleChickdf = Chickdf[Chickdf['calories'] < 600]

# %%
simpleChickdf['calories'].mean()
# Out:
# np.float64(326.25)

# %%
Mcdf = df[df['restaurant'] == 'Mcdonalds']

# %%
Mcdf.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
plt.hist(Mcdf['calories'])
# Out:
# (array([12., 21., 14.,  4.,  2.,  1.,  1.,  1.,  0.,  1.]),
#  array([ 140.,  369.,  598.,  827., 1056., 1285., 1514., 1743., 1972.,
#         2201., 2430.]),
#  <BarContainer object of 10 artists>)

# %%
Mcdf[Mcdf['calories'] > 1200]
# Out:
#    restaurant                                              item  calories  \
# 37  Mcdonalds        10 piece Buttermilk Crispy Chicken Tenders      1210
# 38  Mcdonalds        12 piece Buttermilk Crispy Chicken Tenders      1510
# 39  Mcdonalds        20 piece Buttermilk Crispy Chicken Tenders      2430
# 44  Mcdonalds                        40 piece Chicken McNuggets      1770
# 47  Mcdonalds  10 piece Sweet N' Spicy Honey BBQ Glazed Tenders      1600
#
#     cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  \
# 37      630         70     12.0        1.0          240    3230          52
# 38      790         88     15.0        1.0          295    3770          64
# 39     1270        141     24.0        2.0          475    6080         103
# 44      960        107     18.0        0.5          295    3370         105
# 47      600         66     10.0        0.0          265    4450         156
#
#     fiber  sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
Mcdf[Mcdf['calories'] > 1130]
# Out:
#    restaurant                                              item  calories  \
# 37  Mcdonalds        10 piece Buttermilk Crispy Chicken Tenders      1210
# 38  Mcdonalds        12 piece Buttermilk Crispy Chicken Tenders      1510
# 39  Mcdonalds        20 piece Buttermilk Crispy Chicken Tenders      2430
# 44  Mcdonalds                        40 piece Chicken McNuggets      1770
# 47  Mcdonalds  10 piece Sweet N' Spicy Honey BBQ Glazed Tenders      1600
#
#     cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  \
# 37      630         70     12.0        1.0          240    3230          52
# 38      790         88     15.0        1.0          295    3770          64
# 39     1270        141     24.0        2.0          475    6080         103
# 44      960        107     18.0        0.5          295    3370         105
# 47      600         66     10.0        0.0          265    4450         156
#
#     fiber  sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
simpleMcdf = Mcdf[Mcdf['calories'] < 1140]

# %%
simpleMcdf.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
simpleMcdf['calories'].mean()
# Out:
# np.float64(538.0769230769231)

# %%
simpleChickdf['calories'].mean()
# Out:
# np.float64(326.25)

# %%
simpleChickdf[simpleChickdf['item'] == 'Smokehouse BBQ Bacon Sandwich']
# Out:
#      restaurant                           item  calories  cal_fat  total_fat  \
# 78  Chick Fil-A  Smokehouse BBQ Bacon Sandwich       500      162         18
#
#     sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 78      0.0        0.0           95    1200          46    2.0     10
#
#     protein  vit_a  vit_c  calcium  salad
# 78     33.0   45.0   40.0     20.0  Other

# %%
simpleMcdf[simpleMcdf['item'] == 'Grilled Bacon Smokehouse Chicken Sandwich']
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 3         31     10.0        0.5          155    1940          62    2.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# 3     18     55.0    6.0   25.0     20.0  Other

# %%
### TRANS FATS

# %%
simpleMcdf[simpleMcdf['trans_fat'] > 0]
# Out:
#    restaurant                                       item  calories  cal_fat  \
# 1   Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2   Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3   Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4   Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
# 5   Mcdonalds                                    Big Mac       540      250
# 6   Mcdonalds                               Cheeseburger       300      100
# 8   Mcdonalds                        Double Cheeseburger       430      190
# 9   Mcdonalds        Double Quarter Pounder® with Cheese       770      400
# 11  Mcdonalds                Garlic White Cheddar Burger       620      300
# 16  Mcdonalds            Maple Bacon Dijon 1/4 lb Burger       640      330
# 18  Mcdonalds  Crispy Maple Bacon Dijon Chicken Sandwich       740      310
# ...

# %%
simpleChickdf[simpleChickdf['trans_fat'] > 0]
# Out:
# Empty DataFrame
# Columns: [restaurant, item, calories, cal_fat, total_fat, sat_fat, trans_fat, cholesterol, sodium, total_carb, fiber, sugar, protein, vit_a, vit_c, calcium, salad]
# Index: []

# %%
plt.hist(simpleChickdf['sodium'])
# Out:
# (array([3., 2., 2., 3., 2., 4., 2., 2., 2., 2.]),
#  array([ 220.,  374.,  528.,  682.,  836.,  990., 1144., 1298., 1452.,
#         1606., 1760.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(simpleMcdf['sodium'])
# Out:
# (array([ 1.,  4.,  7., 13., 11.,  5.,  4.,  6.,  0.,  1.]),
#  array([  20.,  285.,  550.,  815., 1080., 1345., 1610., 1875., 2140.,
#         2405., 2670.]),
#  <BarContainer object of 10 artists>)

# %%
Mcdf['calories'].mean()
# Out:
# np.float64(640.3508771929825)

# %%
plt.hist(Mcdf['sodium'])
plt.title('Sodium Distribution')
plt.xlabel('Sodium')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
Mcdf['cal_fat'].mean()
# Out:
# np.float64(285.6140350877193)

# %%
Chickdf['cal_fat'].mean()
# Out:
# np.float64(145.37037037037038)

# %%
plt.scatter(Chickdf['protein'], Chickdf['calories'])

# %%
Chickdf[Chickdf['protein'] > 100]
# Out:
#      restaurant                      item  calories  cal_fat  total_fat  \
# 69  Chick Fil-A  30 piece Chicken Nuggets       970      414         46
#
#     sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 69      2.5        0.0          285    3660          35    4.0      1
#
#     protein  vit_a  vit_c  calcium  salad
# 69    103.0    NaN   20.0     10.0  Other

# %%
plt.scatter(Mcdf['protein'], Mcdf['calories'])

# %%
Mcdf[Mcdf['calories'] < 1000]
# Out:
#    restaurant                                               item  calories  \
# 0   Mcdonalds                   Artisan Grilled Chicken Sandwich       380
# 1   Mcdonalds                     Single Bacon Smokehouse Burger       840
# 3   Mcdonalds          Grilled Bacon Smokehouse Chicken Sandwich       750
# 4   Mcdonalds           Crispy Bacon Smokehouse Chicken Sandwich       920
# 5   Mcdonalds                                            Big Mac       540
# 6   Mcdonalds                                       Cheeseburger       300
# 7   Mcdonalds                           Classic Chicken Sandwich       510
# 8   Mcdonalds                                Double Cheeseburger       430
# 9   Mcdonalds                Double Quarter Pounder® with Cheese       770
# 10  Mcdonalds                                      Filet-O-Fish®       380
# 11  Mcdonalds                        Garlic White Cheddar Burger       620
# ...

# %%
plt.scatter(Mcdf['calories'], Mcdf['sodium'])

# %%
Subwaydf = df[df['restaurant'] == 'Subway']

# %%
tbdf = df[df['restaurant'] == 'Taco Bell']

# %%
plt.scatter(subwaydf['calories'], subwaydf['cal_fat'])

# %%
plt.scatter(tbdf['calories'], tbdf['cal_fat'])

# %%
slope, intercept = np.polyfit(tbdf['calories'], tbdf['cal_fat'], 1)

# %%
tb_regression_line = slope * tbdf['calories'] + intercept

# %%
intercept
# Out:
# np.float64(3.0480681346819707)

# %%
plt.xlim(0, 1300)
plt.ylim(0, 500)
plt.plot(tbdf['calories'], tb_regression_line, color='red')

# %%
sub_slope, sub_intercept = np.polyfit(subwaydf['calories'], subwaydf['cal_fat'], 1)
sub_regression_line = sub_slope * subwaydf['calories'] + sub_intercept
plt.xlim(0, 1300)
plt.ylim(0, 500)
plt.plot(subwaydf['calories'], sub_regression_line, color='red')
